# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilesh-rgb/Hangman-Game-Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install and import required libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.metrics import classification_report, confusion_matrix

print("All libraries loaded successfully!")
# Out:
# All libraries loaded successfully!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# List everything in your Google Drive root
for item in os.listdir('/content/drive/MyDrive'):
    print(item)
# Out:
# Montage
# WhatsApp Image 2022-12-19 at 7.18.16 PM.jpeg
# WhatsApp Image 2022-12-18 at 2.52.17 PM.jpeg
# image001.png
# My Video.mp4
# 55BC26B8-F736-4EA8-A7E4-A618AE8C0D0F.jpg
# C84EA723-D773-474B-94A4-E6B570E7AB9E.jpeg
# payment_receipt_09-Jun-2024_1407 (1).pdf
# Letter of Acceptance - Deposit - 0033b00002s41tm.pdf
# payment_receipt_09-Jun-2024_1409.PDF
# SEO.png
# Untitled (23).png
# Project.gsite
# Portfolio.gsite
# Untitled spreadsheet (1).gsheet
# Nikhilesh Iyer Resume (UPDATED).docx
# Nikhilesh Iyer Resume (UPDATED).pdf
# Help App
# Untitled spreadsheet.gsheet
# LOR(neelam mam) final.docx
# LOR(Prashant Sir) final.docx
# Ireland.gsheet
# NIKHILESH'S LIVE PORTFOLIO.gsheet
# Colab Notebooks
# archive.zip

# %%
import zipfile
import os

# Correct path
zip_path = '/content/drive/MyDrive/archive.zip'
extract_path = '/content/chest_xray'

print("Unzipping... this may take a few minutes")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Done! Let's check the folders:")
for item in os.listdir(extract_path):
    print(item)
# Out:
# Unzipping... this may take a few minutes
# Done! Let's check the folders:
# chest_xray

# %%
for item in os.listdir('/content/chest_xray/chest_xray'):
    print(item)
# Out:
# __MACOSX
# val
# test
# chest_xray
# train

# %%
import os

base_dir = '/content/chest_xray/chest_xray'

for split in ['train', 'val', 'test']:
    split_path = os.path.join(base_dir, split)
    for category in os.listdir(split_path):
        cat_path = os.path.join(split_path, category)
        count = len(os.listdir(cat_path))
        print(f"{split}/{category}: {count} images")
# Out:
# train/NORMAL: 1341 images
# train/PNEUMONIA: 3875 images
# val/NORMAL: 8 images
# val/PNEUMONIA: 8 images
# test/NORMAL: 234 images
# test/PNEUMONIA: 390 images

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

base_dir = '/content/chest_xray/chest_xray'

# Data preparation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    base_dir + '/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    base_dir + '/val',
    target_size=(224, 224),
    batch_size=8,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    base_dir + '/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Build model using VGG16 transfer learning
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze base layers

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Train the model
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[early_stop]
)

print("Training complete!")
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3077s 19s/step - accuracy: 0.7220 - loss: 0.5586 - val_accuracy: 0.5000 - val_loss: 0.7959
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3063s 19s/step - accuracy: 0.7859 - loss: 0.4340 - val_accuracy: 0.5625 - val_loss: 0.6959
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3027s 19s/step - accuracy: 0.8414 - loss: 0.3581 - val_accuracy: 0.5625 - val_loss: 0.6916
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3016s 18s/step - accuracy: 0.8783 - loss: 0.3053 - val_accuracy: 0.6250 - val_loss: 0.6625
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3015s 18s/step - accuracy: 0.8882 - loss: 0.2780 - val_accuracy: 0.6250 - val_loss: 0.6611
# Epoch 6/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3012s 18s/step - accuracy: 0.9039 - loss: 0.2555 - val_accuracy: 0.6875 - val_loss: 0.6502
# Epoch 7/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3001s 18s/step - accuracy: 0.9087 - loss: 0.2390 - val_accuracy: 0.6875 - val_loss: 0.6604
# Epoch 8/10
# ...

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
import os

os.makedirs('/content/figures', exist_ok=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/archive.zip'
extract_path = '/content/chest_xray'

print("Unzipping... please wait")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Done!")
# Out:
# Unzipping... please wait
# Done!

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

base_dir = '/content/chest_xray/chest_xray'

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    base_dir + '/train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'
)
val_generator = val_test_datagen.flow_from_directory(
    base_dir + '/val',
    target_size=(224, 224),
    batch_size=8,
    class_mode='binary'
)
test_generator = val_test_datagen.flow_from_directory(
    base_dir + '/test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

print("Data loaded!")
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Data loaded!

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print("Model built!")
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model built!

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os

os.makedirs('/content/figures', exist_ok=True)

# %%
history_data = {
    'accuracy': [0.7220, 0.7859, 0.8414, 0.8783, 0.8882, 0.9039, 0.9087, 0.9118, 0.9193],
    'val_accuracy': [0.5000, 0.5625, 0.5625, 0.6250, 0.6250, 0.6875, 0.6875, 0.6875, 0.7500],
    'loss': [0.5586, 0.4340, 0.3581, 0.3053, 0.2780, 0.2555, 0.2390, 0.2311, 0.2183],
    'val_loss': [0.7959, 0.6959, 0.6916, 0.6625, 0.6611, 0.6502, 0.6604, 0.6661, 0.6508]
}

# %%
plt.figure(figsize=(10, 6))
plt.plot(history_data['accuracy'], label='Train Accuracy', marker='o')
plt.plot(history_data['val_accuracy'], label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/figures/accuracy_plot.pdf')
plt.savefig('/content/figures/accuracy_plot.png')
plt.show()
print("Accuracy plot saved!")
# Out:
# Accuracy plot saved!

# %%
from google.colab import files
files.download('/content/figures/accuracy_plot.png')

# %%
plt.figure(figsize=(10, 6))
plt.plot(history_data['loss'], label='Train Loss', marker='o')
plt.plot(history_data['val_loss'], label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('/content/figures/loss_plot.pdf')
plt.savefig('/content/figures/loss_plot.png')
plt.show()
print("Loss plot saved!")
# Out:
# Loss plot saved!

# %%
from google.colab import files
files.download('/content/figures/loss_plot.png')

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    callbacks=[early_stop]
)

# Save immediately after training
model.save('/content/drive/MyDrive/pneumonia_model.h5')
print("Training complete and model saved!")
# Out:
# Epoch 1/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3402s 21s/step - accuracy: 0.7711 - loss: 0.4678 - val_accuracy: 0.5625 - val_loss: 0.6936
# Epoch 2/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3406s 21s/step - accuracy: 0.8292 - loss: 0.3752 - val_accuracy: 0.6250 - val_loss: 0.6377
# Epoch 3/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3370s 21s/step - accuracy: 0.8712 - loss: 0.3152 - val_accuracy: 0.6250 - val_loss: 0.6816
# Epoch 4/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3364s 21s/step - accuracy: 0.8869 - loss: 0.2818 - val_accuracy: 0.6250 - val_loss: 0.6886
# Epoch 5/10
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 3364s 21s/step - accuracy: 0.8992 - loss: 0.2578 - val_accuracy: 0.6875 - val_loss: 0.6690
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import os

os.makedirs('/content/figures', exist_ok=True)

# Run predictions on test set
print("Running predictions...")
test_generator.reset()
predictions = model.predict(test_generator, verbose=1)
predicted_classes = (predictions > 0.5).astype(int).flatten()
true_classes = test_generator.classes
class_labels = ['NORMAL', 'PNEUMONIA']

# Confusion Matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels,
            yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('/content/figures/confusion_matrix.pdf')
plt.savefig('/content/figures/confusion_matrix.png')
plt.show()
print("Confusion matrix saved!")

# Classification Report
print("\nClassification Report:")
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Te
# Out:
# Running predictions...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 397s 20s/step
# Confusion matrix saved!
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.92      0.40      0.56       234
#    PNEUMONIA       0.73      0.98      0.84       390
#
#     accuracy                           0.76       624
#    macro avg       0.83      0.69      0.70       624
# weighted avg       0.80      0.76      0.73       624

# %%
from google.colab import files
files.download('/content/figures/confusion_matrix.png')

# %%
from google.colab import files
files.download('/content/figures/accuracy_plot.pdf')
files.download('/content/figures/loss_plot.pdf')
files.download('/content/figures/confusion_matrix.pdf')
